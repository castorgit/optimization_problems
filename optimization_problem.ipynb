# %%
# %load_ext autoreload
# %autoreload 2
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" # use all for maximum output

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
lines = [[[32100, 31850, 4500], [32100, 32200, 4500]], 
         [[32100, 32200, 4500], [31700, 32200, 4500]],
         [[31700, 32200, 4500], [31700, 31850, 4500]],
         [[31700, 31850, 4500], [32100, 31850, 4500]],
        ]
point1 = [31900, 31850, 4500]

# %%
fig = plt.figure(figsize=(12,10))
ax1 = fig.add_subplot(111, projection='3d')
for i in range(4):
   ax1.plot([lines[i][0][0], lines[i][1][0]], [lines[i][0][1], lines[i][1][1]],
            [lines[i][0][2], lines[i][1][2]], color = 'g')
ax1.scatter(point1[0], point1[1], point1[2], s=40, 
           cmap=plt.cm.get_cmap('Spectral'), alpha=0.5, color = 'r')

# %% [markdown]
# find the optimal place for 1 additional point with the constrain to be in the green line
# Optimal means that has the maximum Euclidean distance to P1.
# find the optimal place with 2 points (same rules)
# find the optimal place with 3 points (same rules)

# %%
# 1 point

fx = point1[0] 
fy = point1[1]
fz = point1[2]

print(fx, fy, fz)
# Out:
# 31900 31850 4500
